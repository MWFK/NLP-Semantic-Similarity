# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Almighty\Python workspace\ClinicalNet\Data\All_Batches.xlsx', index=False)
df.head()
# Out:
#    Rank        NCTId                                        OrgFullName  \
# 0     1  NCT03581708             Guangdong Provincial People's Hospital
# 1     2  NCT01130285         University of Toledo Health Science Campus
# 2     3  NCT03992833  Tianjin Medical University Cancer Institute an...
# 3     4  NCT02725892                                        AstraZeneca
# 4     5  NCT00897650                    Vanderbilt-Ingram Cancer Center
#
#                                        OfficialTitle           OverallStatus  \
# 0  Real-world Study of the Incidence and Risk Fac...      Not yet recruiting
# 1  Validation of a Multi-gene Test for Lung Cance...  Active, not recruiting
# 2  Methods of Computed Tomography Screening and M...              Recruiting
# 3         LuCaReAl: Lung Cancer Registry in Algeria.               Completed
# 4  Molecular Fingerprints in Lung Cancer: Predict...               Completed
#
#                                      Keyword  \
# ...

# %%
import numpy as np
df_split = np.array_split(df, 4)

# %%
df_split[1].head()
# Out:
#       Rank        NCTId                         OrgFullName  \
# 2538  2539  NCT02831491               Eli Lilly and Company
# 2539  2540  NCT00606021               Eli Lilly and Company
# 2540  2541  NCT02456246  University Health Network, Toronto
# 2541  2542  NCT03041311               G1 Therapeutics, Inc.
# 2542  2543  NCT03515837           Merck Sharp & Dohme Corp.
#
#                                           OfficialTitle  \
# 2538  A Single-Arm, Phase 2 Study of Ramucirumab in ...
# 2539  A Randomized Phase 2 Study Comparing Pemetrexe...
# 2540  Piloting the Feasibility of FLT-PET/CT Non-Sma...
# 2541  Phase 2 Study of Carboplatin, Etoposide, and A...
# 2542  A Randomized, Double-Blind, Phase 3 Study of P...
#
#                OverallStatus  \
# 2538               Withdrawn
# 2539               Completed
# 2540  Active, not recruiting
# 2541  Active, not recruiting
# 2542  Active, not recruiting
#
#                                                 Keyword  \
# ...

# %%
df_split[0].to_csv(r'C:\Users\Almighty\Python workspace\ClinicalNet\Data\Batches\Batches_0.csv', index=False)
df_split[1].to_csv(r'C:\Users\Almighty\Python workspace\ClinicalNet\Data\Batches\Batches_1.csv', index=False)
df_split[2].to_csv(r'C:\Users\Almighty\Python workspace\ClinicalNet\Data\Batches\Batches_2.csv', index=False)
df_split[3].to_csv(r'C:\Users\Almighty\Python workspace\ClinicalNet\Data\Batches\Batches_3.csv', index=False)
